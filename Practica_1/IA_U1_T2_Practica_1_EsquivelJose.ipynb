# %% [markdown]
# <a href="https://colab.research.google.com/github/jose-esquivel-dev/Inteligencia_Artificial/blob/main/Practica_1/IA_U1_T2_Practica_1_EsquivelJose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#libreria de matplot (para graficas, colores,etc)
import matplotlib.pyplot as plt
#Libreria de seaborn
import seaborn as sns

# %% [markdown]
# # **Ejercicio 2**

# %%
# importacion de la libreria pandas y csv de la informacion
import pandas as pd
info_comp = pd.read_csv('/content/drive/MyDrive/T-Escuela_8/Inteligencia Artifical/Python/U1/Ejercicio 1/Forbes_2000_top_company.csv')
info_comp
# Out:
#       2022 Ranking                          Organization Name  \
# 0                1                         Berkshire Hathaway
# 1                2                                       ICBC
# 2                3   Saudi Arabian Oil Company (Saudi Aramco)
# 3                4                             JPMorgan Chase
# 4                5                    China Construction Bank
# ...            ...                                        ...
# 1994          1995                                     Aperam
# 1995          1995  Shenzhen Feima International Supply Chain
# 1996          1997                                       NMDC
# 1997          1997                 Sichuan Changhong Electric
# 1998          1999                         Satellite Chemical
#
#                           Industry        Country  Year Founded  \
# 0           Diversified Financials  United States          1939
# 1                          Banking          China          1984
# 2             Oil & Gas Operations   Saudi Arabia          1933
# 3           Diversified Financials  United States          2000
# 4                          Banking          China          2014
# ...                            ...            ...           ...
# 1994                     Materials     Luxembourg          2010
# 1995  Business Services & Supplies          China          1998
# 1996                     Materials          India          1958
# 1997             Consumer Durables          China          1988
# 1998                     Chemicals          China             0
#
#                            CEO  Revenue (Billions)  Profits (Billions)  \
# 0        Warren Edward Buffett              276.09               89.80
# 1                       Shu Gu              208.13               54.03
# 2     Amin bin Hasan Al-Nasser              400.38              105.36
# 3                  Jamie Dimon              124.54               42.12
# 4                    Wang Zuji              202.07               46.89
# ...                        ...                 ...                 ...
# 1994          Timoteo di Maulo                6.03                1.14
# 1995            Shan Min Huang                0.04                1.41
# 1996                 Sumit Deb                3.52                1.41
# 1997                    Wei Li               15.72                0.05
# 1998                   No Data                4.41                0.93
#
#       Assets (Billions)  Market Value (Billions)  Total Employees
# 0                958.78                   741.48           372000
# 1               5518.51                   214.42           449296
# 2                576.04                  2292.08            68493
# 3               3954.69                   374.45           271025
# 4               4746.95                   181.32           352621
# ...                 ...                      ...              ...
# 1994               6.72                     3.16                0
# 1995               0.17                     1.14              306
# 1996               5.72                     6.40            16944
# 1997              12.10                     1.96            51841
# 1998               7.64                     9.52             3409
#
# [1999 rows x 11 columns]

# %%
#Columnas del csv
info_comp.columns
# Out:
# Index(['2022 Ranking', 'Organization Name', 'Industry', 'Country',
#        'Year Founded', 'CEO', 'Revenue (Billions)', 'Profits (Billions)',
#        'Assets (Billions)', 'Market Value (Billions)', 'Total Employees'],
#       dtype='object')

# %%
#Columnas de tipo numericas
#Filtramos por valores para utilizarlos luego y saber cuales pueden servirnos
info_comp.select_dtypes(include=['number']).sort_values('Assets (Billions)', ascending=False)
# Out:
#       2022 Ranking  Year Founded  Revenue (Billions)  Profits (Billions)  \
# 1                2          1984              208.13               54.03
# 4                5          2014              202.07               46.89
# 7                8          1979              181.42               37.38
# 337            338          1938              100.33               22.18
# 12              13          1929              152.43               33.57
# ...            ...           ...                 ...                 ...
# 1574          1575             0               41.81               -1.57
# 1904          1905          1993               17.64                0.04
# 1942          1943             0                0.00                1.50
# 1745          1746          2005                0.35                0.08
# 1995          1995          1998                0.04                1.41
#
#       Assets (Billions)  Market Value (Billions)  Total Employees
# 1               5518.51                   214.42           449296
# 4               4746.95                   181.32           352621
# 7               4561.05                   133.38           455174
# 337             4229.90                     0.88             7400
# 12              4192.84                   117.82           306322
# ...                 ...                      ...              ...
# 1574               1.62                     1.21            36992
# 1904               1.54                     0.56                0
# 1942               1.36                     2.43                0
# 1745               0.50                    34.74              517
# 1995               0.17                     1.14              306
#
# [1999 rows x 7 columns]

# %%
#Columnas de tipo texto
#Filtramos por texto para utilizarlos luego y saber cuales pueden servirnos
info_comp.select_dtypes(include=['object','string'])
# Out:
#                               Organization Name                      Industry  \
# 0                            Berkshire Hathaway        Diversified Financials
# 1                                          ICBC                       Banking
# 2      Saudi Arabian Oil Company (Saudi Aramco)          Oil & Gas Operations
# 3                                JPMorgan Chase        Diversified Financials
# 4                       China Construction Bank                       Banking
# ...                                         ...                           ...
# 1994                                     Aperam                     Materials
# 1995  Shenzhen Feima International Supply Chain  Business Services & Supplies
# 1996                                       NMDC                     Materials
# 1997                 Sichuan Changhong Electric             Consumer Durables
# 1998                         Satellite Chemical                     Chemicals
#
#             Country                       CEO
# 0     United States     Warren Edward Buffett
# 1             China                    Shu Gu
# 2      Saudi Arabia  Amin bin Hasan Al-Nasser
# 3     United States               Jamie Dimon
# 4             China                 Wang Zuji
# ...             ...                       ...
# 1994     Luxembourg          Timoteo di Maulo
# 1995          China            Shan Min Huang
# 1996          India                 Sumit Deb
# 1997          China                    Wei Li
# 1998          China                   No Data
#
# [1999 rows x 4 columns]

# %% [markdown]
# ## Grafica de barras

# %%
# Seleccionamos las 10 empresas con mayor valor de mercado
top_empresas = info_comp.nlargest(10, 'Market Value (Billions)')

# Creamos la gráfica de barras
top_empresas.plot(
    kind='bar',
    x='Organization Name',
    y='Market Value (Billions)',
    color='skyblue',
    edgecolor='black'
)
plt.title('Top 10 Empresas por Valor de Mercado')
plt.xlabel('Empresa')
plt.ylabel('Valor de Mercado (Billones USD)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Agrupamos por industria y sumamos su valor de mercado, tomando las 10 principales
mercado_industria = (
    info_comp.groupby('Industry')['Market Value (Billions)']
    .sum()
    .nlargest(10)
)

# Gráfica
mercado_industria.plot(kind='bar', color='salmon', edgecolor='black')
plt.title('Top 10 Industrias por Valor de Mercado Acumulado')
plt.xlabel('Industria')
plt.ylabel('Valor Total (Billones USD)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Contamos cuántas empresas hay por país y tomamos el top 10
top_paises = info_comp['Country'].value_counts().head(10)

# Gráfica
top_paises.plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title('Top 10 Países con Más Empresas en el Ranking')
plt.xlabel('País')
plt.ylabel('Cantidad de Empresas')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Top 10 por ingresos
top_ingresos = info_comp.nlargest(10, 'Revenue (Billions)')

# Gráfica
top_ingresos.plot(
    kind='bar',
    x='Organization Name',
    y='Revenue (Billions)',
    color='gold',
    edgecolor='black'
)
plt.title('Top 10 Empresas con Mayores Ingresos')
plt.xlabel('Empresa')
plt.ylabel('Ingresos (Billones USD)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Top 10 por número de empleados
top_empleados = info_comp.nlargest(10, 'Total Employees')

# Gráfica
top_empleados.plot(
    kind='bar',
    x='Organization Name',
    y='Total Employees',
    color='mediumpurple',
    edgecolor='black'
)
plt.title('Top 10 Empresas con Mayor Número de Empleados')
plt.xlabel('Empresa')
plt.ylabel('Total de Empleados')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## **Grafica BoxPlot**

# %%
#Grafica boxplot con Matplotlib
plt.boxplot(info_comp['Total Employees'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d7c9eec6990>,
#   <matplotlib.lines.Line2D at 0x7d7c9eec6ad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d7c9eec6c10>,
#   <matplotlib.lines.Line2D at 0x7d7c9eec6d50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d7c9eec6850>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d7c9eec6e90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d7c9eec6fd0>],
#  'means': []}

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=info_comp['Revenue (Billions)'], color='skyblue')
plt.title('Diagrama de Caja: Ingresos (Revenue)')
plt.xlabel('Ingresos en Billones')
plt.show()

# %% [markdown]
# ## **Grafica de Dispercion**

# %%
print(info_comp['Market Value (Billions)'].mean().round(2))
print(info_comp['Assets (Billions)'].mean().round(2))
# Out:
# 38.26
# 117.18

# %%
#Grafica de dispersion con Matplotlib
activos = info_comp['Assets (Billions)']
valor_mercado = info_comp['Market Value (Billions)']
plt.scatter(valor_mercado, activos)
plt.xlim(0, 38)
plt.ylim(0, 117)
plt.xlabel('Valor en el Mercado')
plt.ylabel('Activos en el Mercado')
# Out:
# Text(0, 0.5, 'Activos en el Mercado')

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=info_comp, x='Assets (Billions)', y='Market Value (Billions)', alpha=0.7, color='coral')
plt.title('Dispersión: Activos vs. Valor de Mercado')
plt.xlabel('Activos (Billones)')
plt.ylabel('Valor de Mercado (Billones)')
plt.show()

# %% [markdown]
# ## **Grafica de Calor**

# %%
# Grafica de calor con pandas
sns.heatmap(round(info_comp.corr(numeric_only=True),2), annot=True)
# Out:
# <Axes: >
